# %% [markdown]
# Step 1: Import Necessary libraries

# %%
import pandas as pd
import requests
# Out:
# /tmp/ipykernel_19546/1058106858.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url = "http://api.coincap.io/v2/assets"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
responsedata = response.json()
responsedata
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19642150.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1227650565536.9775209764805200',
#    'volumeUsd24Hr': '11986817704.8898693295488357',
#    'priceUsd': '62500.8242751927625528',
#    'changePercent24Hr': '1.6200735325408098',
#    'vwap24Hr': '61888.9774167814409747',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120142083.8889959300000000',
#    'maxSupply': None,
#    'marketCapUsd': '412941756547.4896949549995262',
#    'volumeUsd24Hr': '6263091681.9759107837191962',
#    'priceUsd': '3437.1116529743489174',
#    'changePercent24Hr': '2.4781714260341641',
#    'vwap24Hr': '3403.0257068531811405',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '98798027729.4258700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '98884510857.6484185612044514',
#    'volumeUsd24Hr': '25261496631.0563336917951265',
#    'priceUsd': '1.0008753527799097',
#    'changePercent24Hr': '0.0155857019675373',
#    'vwap24Hr': '1.0003141333947072',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '68019227592.9661624173445036',
#    'volumeUsd24Hr': '368456630.3002041077465428',
#    'priceUsd': '407.7863276634412757',
#    'changePercent24Hr': '1.7736080500951770',
#    'vwap24Hr': '405.4560733436612830',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '442825850.6403168000000000',
#    'maxSupply': None,
#    'marketCapUsd': '57954352250.4444122682251761',
#    'volumeUsd24Hr': '1531722479.3831709204803637',
#    'priceUsd': '130.8739139023696257',
#    'changePercent24Hr': '3.8194157105810509',
#    'vwap24Hr': '132.7515549643320709',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '28989461792.6760500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '28987080273.7125990618781261',
#    'volumeUsd24Hr': '1679511107.8529763695615226',
#    'priceUsd': '0.9999178488038004',
#    'changePercent24Hr': '-0.0202064113076648',
#    'vwap24Hr': '0.9997720932447095',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '27307864847.7209133558097120',
#    'volumeUsd24Hr': '629037290.0525740357199036',
#    'priceUsd': '0.6014414505866833',
#    'changePercent24Hr': '2.0274818313785241',
#    'vwap24Hr': '0.5920586438989315',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'cardano',
#    'rank': '8',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35479797493.9420000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '25024473173.8789121200805592',
#    'volumeUsd24Hr': '419096964.3453224090766115',
#    'priceUsd': '0.7053161218902593',
#    'changePercent24Hr': '6.9104622488861928',
#    'vwap24Hr': '0.6804977369067026',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'dogecoin',
#    'rank': '9',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '143292126383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '20231506339.8271956634462033',
#    'volumeUsd24Hr': '1994755679.0891321018994627',
#    'priceUsd': '0.1411906351759455',
#    'changePercent24Hr': '19.4397160279323588',
#    'vwap24Hr': '0.1282041671504143',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'avalanche',
#    'rank': '10',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '377240067.5484341400000000',
#    'maxSupply': '720000000.0000000000000000',
#    'marketCapUsd': '16096268724.1323883742851407',
#    'volumeUsd24Hr': '293483050.7499329796140643',
#    'priceUsd': '42.6685023908966832',
#    'changePercent24Hr': '4.1207340795274040',
#    'vwap24Hr': '42.1966754815250813',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'tron',
#    'rank': '11',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87970940707.7935500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '12461571349.6490928002451776',
#    'volumeUsd24Hr': '152816716.3562097728861862',
#    'priceUsd': '0.1416555427211101',
#    'changePercent24Hr': '0.6540066446289757',
#    'vwap24Hr': '0.1411177545690833',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'chainlink',
#    'rank': '12',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '587099970.4527867000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '11770496446.9124320356473916',
#    'volumeUsd24Hr': '288015143.8019131663199196',
#    'priceUsd': '20.0485386463820129',
#    'changePercent24Hr': '3.8165306996165971',
#    'vwap24Hr': '19.7672176703363860',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'polkadot',
#    'rank': '13',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1336089511.4624300000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11532908101.4595846130915499',
#    'volumeUsd24Hr': '178774546.4917897781517898',
#    'priceUsd': '8.6318379139404559',
#    'changePercent24Hr': '4.4180010500841487',
#    'vwap24Hr': '8.4063307160609014',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'polygon',
#    'rank': '14',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9899153489.5402160000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '10150266480.7710590973782563',
#    'volumeUsd24Hr': '215246596.0140223818616717',
#    'priceUsd': '1.0253671176526536',
#    'changePercent24Hr': '2.0695356316393937',
#    'vwap24Hr': '1.0192633807656203',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '15',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '155985.9022946900000000',
#    'maxSupply': None,
#    'marketCapUsd': '9758302896.4855260973666912',
#    'volumeUsd24Hr': '143619933.9138710424590821',
#    'priceUsd': '62558.8771352557912213',
#    'changePercent24Hr': '1.7309952688610312',
#    'vwap24Hr': '61850.2521384016582273',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'shiba-inu',
#    'rank': '16',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589289556161287.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '9696946563.7418701173203022',
#    'volumeUsd24Hr': '914168836.1622279132604123',
#    'priceUsd': '0.0000164553171906',
#    'changePercent24Hr': '30.1710478432788808',
#    'vwap24Hr': '0.0000143574364061',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'uniswap',
#    'rank': '17',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '598736139.7100000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '6964709820.5247842775468315',
#    'volumeUsd24Hr': '226424020.0026523349637922',
#    'priceUsd': '11.6323524815090776',
#    'changePercent24Hr': '3.4036380030751977',
#    'vwap24Hr': '11.3392538797102930',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'litecoin',
#    'rank': '18',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74263662.3575049300000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '6294161495.1337884923453763',
#    'volumeUsd24Hr': '297106220.0594009443313759',
#    'priceUsd': '84.7542565950184886',
#    'changePercent24Hr': '5.9376655885480960',
#    'vwap24Hr': '83.8492252176095813',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'bitcoin-cash',
#    'rank': '19',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19656243.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '6211469288.3523269073649744',
#    'volumeUsd24Hr': '145071274.8022491650551664',
#    'priceUsd': '316.0048973422161041',
#    'changePercent24Hr': '5.7762167885118540',
#    'vwap24Hr': '312.1182636498891575',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'internet-computer',
#    'rank': '20',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '459568131.1116451000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5952198831.1084990367114055',
#    'volumeUsd24Hr': '68120308.7375753218082519',
#    'priceUsd': '12.9517223413877293',
#    'changePercent24Hr': '1.8720833535595248',
#    'vwap24Hr': '12.8084352328732038',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'multi-collateral-dai',
#    'rank': '21',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5343646782.1131596317399915',
#    'volumeUsd24Hr': '95432803.4935576612981305',
#    'priceUsd': '0.9992068246080104',
#    'changePercent24Hr': '-0.0901886477445630',
#    'vwap24Hr': '1.0019247052084602',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'unus-sed-leo',
#    'rank': '22',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '927245378.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4412687573.4748285400226101',
#    'volumeUsd24Hr': '636177.8924901068283183',
#    'priceUsd': '4.7589210729846308',
#    'changePercent24Hr': '0.0754672340856105',
#    'vwap24Hr': '4.7647779382803119',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'ethereum-classic',
#    'rank': '23',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '145818624.3274436000000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '4409629945.3281367516996486',
#    'volumeUsd24Hr': '108874193.0724095509963438',
#    'priceUsd': '30.2405125934124467',
#    'changePercent24Hr': '4.5079081409977626',
#    'vwap24Hr': '29.5754048045463052',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'stacks',
#    'rank': '24',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1444222097.9851760000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '4296809698.1688375182609509',
#    'volumeUsd24Hr': '46156264.0036398466122451',
#    'priceUsd': '2.9751723811478070',
#    'changePercent24Hr': '1.5371347458330947',
#    'vwap24Hr': '2.9512556138843519',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'filecoin',
#    'rank': '25',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '518501476.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4263644720.3273723431509024',
#    'volumeUsd24Hr': '229657254.4243388770532289',
#    'priceUsd': '8.2230136608663624',
#    'changePercent24Hr': '0.1636319148874839',
#    'vwap24Hr': '8.2164719355826301',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'near-protocol',
#    'rank': '26',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1043761976.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4133747406.9515782664726360',
#    'volumeUsd24Hr': '104871655.2920606442590795',
#    'priceUsd': '3.9604311155243485',
#    'changePercent24Hr': '1.7402062763724520',
#    'vwap24Hr': '3.9757193163041611',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'stellar',
#    'rank': '27',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '28538021798.7821000000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '3628838175.9184295720700073',
#    'volumeUsd24Hr': '62121851.3165858597282447',
#    'priceUsd': '0.1271580140174010',
#    'changePercent24Hr': '4.1552137050909979',
#    'vwap24Hr': '0.1245310965304295',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'vechain',
#    'rank': '28',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '72714516834.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3556965282.2031557535785982',
#    'volumeUsd24Hr': '39383333.1673403283178556',
#    'priceUsd': '0.0489168523298223',
#    'changePercent24Hr': '2.2248480232857721',
#    'vwap24Hr': '0.0482372022526711',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'injective-protocol',
#    'rank': '29',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '3305664913.8102405873433399',
#    'volumeUsd24Hr': '151383541.0557913816144821',
#    'priceUsd': '45.2796358324732494',
#    'changePercent24Hr': '10.0946759139772458',
#    'vwap24Hr': '42.8666106717554760',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'crypto-com-coin',
#    'rank': '30',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '3175557845.8687309128835464',
#    'volumeUsd24Hr': '19121408.8307132872875033',
#    'priceUsd': '0.1256998822303742',
#    'changePercent24Hr': '14.9327731130864348',
#    'vwap24Hr': '0.1153791187976898',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'okb',
#    'rank': '31',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3082773400.6216841340000000',
#    'volumeUsd24Hr': '989597.2135552075940611',
#    'priceUsd': '51.3795566770280689',
#    'changePercent24Hr': '-1.1281616187966507',
#    'vwap24Hr': '51.7247170436824488',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'the-graph',
#    'rank': '32',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9417628484.7250700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3038978720.5889936950923045',
#    'volumeUsd24Hr': '167423048.2513535381303701',
#    'priceUsd': '0.3226904443637873',
#    'changePercent24Hr': '14.5542580990508316',
#    'vwap24Hr': '0.3096445621899251',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'lido-dao',
#    'rank': '33',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '891677582.2362522000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2990068391.5433895648337278',
#    'volumeUsd24Hr': '3508570.5318068064702848',
#    'priceUsd': '3.3533066784571954',
#    'changePercent24Hr': '-0.2464943820653734',
#    'vwap24Hr': '3.3786370772320977',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'render-token',
#    'rank': '34',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2939127872.7674586494352087',
#    'volumeUsd24Hr': '39783129.7750651972199445',
#    'priceUsd': '7.9518844207396109',
#    'changePercent24Hr': '6.6776847483157471',
#    'vwap24Hr': '7.7730748713663761',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'cosmos',
#    'rank': '35',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2877991343.5001530405640869',
#    'volumeUsd24Hr': '87039967.3500735035489814',
#    'priceUsd': '11.5836355978370069',
#    'changePercent24Hr': '2.5041284292410957',
#    'vwap24Hr': '11.3513230943538463',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'monero',
#    'rank': '36',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18404701.2066679400000000',
#    'maxSupply': None,
#    'marketCapUsd': '2662769645.0879425691411258',
#    'volumeUsd24Hr': '43798810.3237725648221314',
#    'priceUsd': '144.6787761011427434',
#    'changePercent24Hr': '4.6622244907177680',
#    'vwap24Hr': '140.7223023570741996',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'bitcoin-bep2',
#    'rank': '37',
#    'symbol': 'BTCB',
#    'name': 'Bitcoin BEP2',
#    'supply': '53998.8096344000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2310871378.2418245775637012',
#    'volumeUsd24Hr': '2403791.8685712000000016',
#    'priceUsd': '42794.8577734884264959',
#    'changePercent24Hr': '-0.0000009892182665',
#    'vwap24Hr': None,
#    'explorer': 'https://explorer.binance.org/asset/BTCB-1DE'},
#   {'id': 'theta',
#    'rank': '38',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2056036859.7577825000000000',
#    'volumeUsd24Hr': '90551257.0275777220501923',
#    'priceUsd': '2.0560368597577825',
#    'changePercent24Hr': '9.0747335818086121',
#    'vwap24Hr': '1.9400577280986937',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'thorchain',
#    'rank': '39',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '340758227.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1975323447.7865050464543745',
#    'volumeUsd24Hr': '66232967.3310501357512888',
#    'priceUsd': '5.7968474163545435',
#    'changePercent24Hr': '0.5024828611752662',
#    'vwap24Hr': '5.7633526106773600',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'maker',
#    'rank': '40',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '923288.1040241200000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '1949040739.3500568430979083',
#    'volumeUsd24Hr': '23069851.6176033401434906',
#    'priceUsd': '2110.9778528015563572',
#    'changePercent24Hr': '0.5789494341558272',
#    'vwap24Hr': '2113.9187749760112878',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'algorand',
#    'rank': '41',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8052738649.8699530000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1816634024.6184283774490225',
#    'volumeUsd24Hr': '53377734.9145490118496004',
#    'priceUsd': '0.2255920753926077',
#    'changePercent24Hr': '6.6629756539125152',
#    'vwap24Hr': '0.2182651372916327',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'arweave',
#    'rank': '42',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65454185.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '1760681119.7096601068170170',
#    'volumeUsd24Hr': '84851004.8753763319472577',
#    'priceUsd': '26.8994430181914282',
#    'changePercent24Hr': '-0.7825400865904073',
#    'vwap24Hr': '27.7465829774151055',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'hedera-hashgraph',
#    'rank': '43',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1723924347.8317756992840696',
#    'volumeUsd24Hr': '40551911.3283829503019905',
#    'priceUsd': '0.1162241423358882',
#    'changePercent24Hr': '1.7127626763605080',
#    'vwap24Hr': '0.1153900126817111',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'flow',
#    'rank': '44',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1492052308.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1687564067.0514923437996540',
#    'volumeUsd24Hr': '38545093.1787945506483629',
#    'priceUsd': '1.1310354590138755',
#    'changePercent24Hr': '6.8528663486710215',
#    'vwap24Hr': '1.0940290958200109',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'bitcoin-sv',
#    'rank': '45',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19649056.2500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1664849334.2288455956062413',
#    'volumeUsd24Hr': '5112275.4815084929137990',
#    'priceUsd': '84.7292263326308914',
#    'changePercent24Hr': '4.5112940973738695',
#    'vwap24Hr': '83.0518819338918824',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'aave',
#    'rank': '46',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14751615.5955142800000000',
#    'maxSupply': '16000000.0000000000000000',
#    'marketCapUsd': '1617262708.8951036382823429',
#    'volumeUsd24Hr': '70010620.3179377729948971',
#    'priceUsd': '109.6329211145446486',
#    'changePercent24Hr': '4.0940081519474815',
#    'vwap24Hr': '108.5880828949032151',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'elrond-egld',
#    'rank': '47',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '1531341617.3617487360687469',
#    'volumeUsd24Hr': '25875369.9899719774136397',
#    'priceUsd': '63.3189799053675562',
#    'changePercent24Hr': '5.0924769041494594',
#    'vwap24Hr': '61.6956538694780728',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'quant',
#    'rank': '48',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '1517236561.2498712577679102',
#    'volumeUsd24Hr': '29976945.7577815579940042',
#    'priceUsd': '125.6746034950705679',
#    'changePercent24Hr': '9.7554816970222137',
#    'vwap24Hr': '120.2682283274586027',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'the-sandbox',
#    'rank': '49',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2241731926.2233224000000000',
#    'maxSupply': '3000000000.0000000000000000',
#    'marketCapUsd': '1486558242.6188260447715747',
#    'volumeUsd24Hr': '94834716.9124150754654432',
#    'priceUsd': '0.6631293533492436',
#    'changePercent24Hr': '10.9646713160478795',
#    'vwap24Hr': '0.6292426704759328',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'helium',
#    'rank': '50',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': '223000000.0000000000000000',
#    'marketCapUsd': '1457877059.0517420927843780',
#    'volumeUsd24Hr': '2288617.5633380844292274',
#    'priceUsd': '9.0621479731179039',
#    'changePercent24Hr': '1.9335317679363541',
#    'vwap24Hr': '9.1059121552787399',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'fetch',
#    'rank': '51',
#    'symbol': 'FET',
#    'name': 'Fetch.ai',
#    'supply': '831840077.3866875000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1444717393.3993024828165980',
#    'volumeUsd24Hr': '368960118.1851261046701413',
#    'priceUsd': '1.7367730080258132',
#    'changePercent24Hr': '19.7307877333413500',
#    'vwap24Hr': '1.6563731999342534',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'chiliz',
#    'rank': '52',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8888290621.6840320000000000',
#    'maxSupply': '8888888888.0000000000000000',
#    'marketCapUsd': '1435738081.8704450399262318',
#    'volumeUsd24Hr': '81385174.6056443129396721',
#    'priceUsd': '0.1615314060914922',
#    'changePercent24Hr': '14.2730202672701915',
#    'vwap24Hr': '0.1572427131204385',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'mina',
#    'rank': '53',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1061221897.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1415782987.5534883055719389',
#    'volumeUsd24Hr': '24325965.3540647457387673',
#    'priceUsd': '1.3341064582582642',
#    'changePercent24Hr': '3.4260076126567670',
#    'vwap24Hr': '1.3095659614493367',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'fantom',
#    'rank': '54',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': '3175000000.0000000000000000',
#    'marketCapUsd': '1372691131.2698855610155871',
#    'volumeUsd24Hr': '78502533.4231905634447963',
#    'priceUsd': '0.4896112410488222',
#    'changePercent24Hr': '5.2038471792079921',
#    'vwap24Hr': '0.4844890033976484',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'axie-infinity',
#    'rank': '55',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '137721716.7303795000000000',
#    'maxSupply': '270000000.0000000000000000',
#    'marketCapUsd': '1364639096.9462696033961108',
#    'volumeUsd24Hr': '68466305.5559578077499848',
#    'priceUsd': '9.9086703923234581',
#    'changePercent24Hr': '6.3621307345759549',
#    'vwap24Hr': '9.5828521398050523',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'trueusd',
#    'rank': '56',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '1288455467.0100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1289132373.4648835918877191',
#    'volumeUsd24Hr': '34821191.7491366686260126',
#    'priceUsd': '1.0005253627092401',
#    'changePercent24Hr': '0.0033621997425967',
#    'vwap24Hr': '0.9988635851621497',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'decentraland',
#    'rank': '57',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1264116426.8229661163612112',
#    'volumeUsd24Hr': '90937221.1864167862538846',
#    'priceUsd': '0.6624237633053036',
#    'changePercent24Hr': '1.8664741975439745',
#    'vwap24Hr': '0.6509286374072486',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'tezos',
#    'rank': '58',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '972723978.9598460000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1242634668.7223228299146321',
#    'volumeUsd24Hr': '27183541.2348545955269880',
#    'priceUsd': '1.2774792187719048',
#    'changePercent24Hr': '3.8880399258381123',
#    'vwap24Hr': '1.2516915917916184',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'kucoin-token',
#    'rank': '59',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '96287258.2890287500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '1196740507.1240463349642478',
#    'volumeUsd24Hr': '3446183.6313026182514169',
#    'priceUsd': '12.4288564072698955',
#    'changePercent24Hr': '8.0669291925105692',
#    'vwap24Hr': '11.8690041043086704',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'singularitynet',
#    'rank': '60',
#    'symbol': 'AGIX',
#    'name': 'SingularityNET',
#    'supply': '1276586403.6498213000000000',
#    'maxSupply': '2000000000.0000000000000000',
#    'marketCapUsd': '1187710574.5735895434006176',
#    'volumeUsd24Hr': '63550635.7817163320762810',
#    'priceUsd': '0.9303800911382641',
#    'changePercent24Hr': '32.3922953130531127',
#    'vwap24Hr': '0.8548096538416212',
#    'explorer': 'https://etherscan.io/token/0x8eb24319393716668d768dcec29356ae9cffe285'},
#   {'id': 'gala',
#    'rank': '61',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '27799861148.4223400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1154928672.0419151654927076',
#    'volumeUsd24Hr': '88827121.2096890547820099',
#    'priceUsd': '0.0415444043362590',
#    'changePercent24Hr': '5.4244722166340995',
#    'vwap24Hr': '0.0400070541987137',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'akash-network',
#    'rank': '62',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '229280561.1350890000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '1099263116.3971287377298539',
#    'volumeUsd24Hr': '824068.7677382578383339',
#    'priceUsd': '4.7944017188158302',
#    'changePercent24Hr': '-1.2485137389577718',
#    'vwap24Hr': '4.8204845245378405',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'neo',
#    'rank': '63',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1092271416.0535626884551622',
#    'volumeUsd24Hr': '65631262.3633595822986577',
#    'priceUsd': '15.4846826998531162',
#    'changePercent24Hr': '8.9902077361188402',
#    'vwap24Hr': '15.4314048801578552',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'oasis-network',
#    'rank': '64',
#    'symbol': 'ROSE',
#    'name': 'Oasis Network',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1085668513.7669863554295240',
#    'volumeUsd24Hr': '37237554.6040582733238406',
#    'priceUsd': '0.1617118287981490',
#    'changePercent24Hr': '6.9967109333666689',
#    'vwap24Hr': '0.1558246895060788',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'synthetix-network-token',
#    'rank': '65',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '1065862836.9730828289053972',
#    'volumeUsd24Hr': '50301794.1628606829061890',
#    'priceUsd': '4.5604900473191310',
#    'changePercent24Hr': '9.2213138202983213',
#    'vwap24Hr': '4.4014910781438824',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'gnosis-gno',
#    'rank': '66',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '1045817519.0909302687398984',
#    'volumeUsd24Hr': '10228668.6753692910700879',
#    'priceUsd': '403.8547904496507818',
#    'changePercent24Hr': '3.9738000135576123',
#    'vwap24Hr': '393.9154951200927294',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'conflux-network',
#    'rank': '67',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '3750669652.5100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1019858754.9335842459767898',
#    'volumeUsd24Hr': '21894889.4962937616978187',
#    'priceUsd': '0.2719137779172529',
#    'changePercent24Hr': '5.4378373453411053',
#    'vwap24Hr': '0.2658120201051132',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'eos',
#    'rank': '68',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1118778401.8738000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1014273980.6871002701497881',
#    'volumeUsd24Hr': '60033220.9525688409973246',
#    'priceUsd': '0.9065905982706949',
#    'changePercent24Hr': '5.4594062350450695',
#    'vwap24Hr': '0.8788770747971841',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'iota',
#    'rank': '69',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3152954445.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '991698035.0843745668452920',
#    'volumeUsd24Hr': '15753714.3257552367415798',
#    'priceUsd': '0.3145297695807256',
#    'changePercent24Hr': '9.3519534220810228',
#    'vwap24Hr': '0.3001718440500239',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'kava',
#    'rank': '70',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082860683.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '990934610.5204354561855140',
#    'volumeUsd24Hr': '26703643.7264421960624070',
#    'priceUsd': '0.9151081261673580',
#    'changePercent24Hr': '6.5450347908476274',
#    'vwap24Hr': '0.8701126012173707',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'wootrade',
#    'rank': '71',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1834677115.6746109000000000',
#    'maxSupply': None,
#    'marketCapUsd': '973361436.4222245451568064',
#    'volumeUsd24Hr': '16689281.5368392984294298',
#    'priceUsd': '0.5305355520632411',
#    'changePercent24Hr': '1.9728630516956073',
#    'vwap24Hr': '0.5294314691759450',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'klaytn',
#    'rank': '72',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3494746035.8895910000000000',
#    'maxSupply': None,
#    'marketCapUsd': '963939244.0394579211156922',
#    'volumeUsd24Hr': '7155502.6325585602957411',
#    'priceUsd': '0.2758252628775316',
#    'changePercent24Hr': '12.0447650575767768',
#    'vwap24Hr': '0.2548067345232253',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'wemix',
#    'rank': '73',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '363925579.9315307000000000',
#    'maxSupply': '980000000.0000000000000000',
#    'marketCapUsd': '855347346.7862324318278946',
#    'volumeUsd24Hr': '4511463.4696531439670802',
#    'priceUsd': '2.3503358762172153',
#    'changePercent24Hr': '2.1192837499845508',
#    'vwap24Hr': '2.3207025232106442',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'pendle',
#    'rank': '74',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '238185588.2446348700000000',
#    'maxSupply': '258446029.0000000000000000',
#    'marketCapUsd': '828991608.0559351716117908',
#    'volumeUsd24Hr': '2174266.1318126884805222',
#    'priceUsd': '3.4804440275559292',
#    'changePercent24Hr': '10.0229253604086943',
#    'vwap24Hr': '3.3783102504343718',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'nexo',
#    'rank': '75',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '785771098.2761188312404049',
#    'volumeUsd24Hr': '2033180.2393839238461503',
#    'priceUsd': '1.4031626479309459',
#    'changePercent24Hr': '3.3128900449478960',
#    'vwap24Hr': '1.3923079898915142',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'ecash',
#    'rank': '76',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19649223423092.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '777537913.3786162163323676',
#    'volumeUsd24Hr': '11550478.7054133160036202',
#    'priceUsd': '0.0000395709233203',
#    'changePercent24Hr': '8.4702569681498208',
#    'vwap24Hr': '0.0000378399753611',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'pancakeswap',
#    'rank': '77',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '241592143.9408225400000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '773116358.4085690795838555',
#    'volumeUsd24Hr': '28098118.0694368190913894',
#    'priceUsd': '3.2000889838451958',
#    'changePercent24Hr': '3.2565408909590831',
#    'vwap24Hr': '3.1560844047494134',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'compound',
#    'rank': '78',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8084752.1026340900000000',
#    'maxSupply': '10000000.0000000000000000',
#    'marketCapUsd': '763795926.3491567452255909',
#    'volumeUsd24Hr': '38884171.5306510604628299',
#    'priceUsd': '94.4736358830723685',
#    'changePercent24Hr': '3.4508471644565092',
#    'vwap24Hr': '92.0386551371392199',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'curve-dao-token',
#    'rank': '79',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1136429660.0000000000000000',
#    'maxSupply': '3303030299.0000000000000000',
#    'marketCapUsd': '740363522.8919865472981420',
#    'volumeUsd24Hr': '14152736.1659693424782623',
#    'priceUsd': '0.6514820485167437',
#    'changePercent24Hr': '9.1023280939738730',
#    'vwap24Hr': '0.6195744842031849',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'frax-share',
#    'rank': '80',
#    'symbol': 'FXS',
#    'name': 'Frax Share',
#    'supply': '77023692.3813440000000000',
#    'maxSupply': None,
#    'marketCapUsd': '711236682.9663702070094578',
#    'volumeUsd24Hr': '953486.1771751973108780',
#    'priceUsd': '9.2339987992920434',
#    'changePercent24Hr': '3.2031844808660776',
#    'vwap24Hr': '9.0720860401762633',
#    'explorer': 'https://etherscan.io/token/0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0'},
#   {'id': 'superfarm',
#    'rank': '81',
#    'symbol': 'SUPER',
#    'name': 'SuperVerse',
#    'supply': '487776093.4169172600000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '687289988.0462251431110148',
#    'volumeUsd24Hr': '22058891.5289824762792457',
#    'priceUsd': '1.4090276200944871',
#    'changePercent24Hr': '12.8723989073071992',
#    'vwap24Hr': '1.3580695723921562',
#    'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'},
#   {'id': 'nervos-network',
#    'rank': '82',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '43644799220.1578400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '684572577.3619367065209152',
#    'volumeUsd24Hr': '39177505.1098483669930772',
#    'priceUsd': '0.0156850893942424',
#    'changePercent24Hr': '3.4789455425183829',
#    'vwap24Hr': '0.0155189293258834',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'dydx',
#    'rank': '83',
#    'symbol': 'DYDX',
#    'name': 'dYdX',
#    'supply': '183765523.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '654820757.0338860186881040',
#    'volumeUsd24Hr': '58781627.7250963398729613',
#    'priceUsd': '3.5633493505410480',
#    'changePercent24Hr': '6.3965701802882200',
#    'vwap24Hr': '3.4421437389970015',
#    'explorer': None},
#   {'id': 'enjin-coin',
#    'rank': '84',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '1379841765.7600000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '639606921.2284889356803839',
#    'volumeUsd24Hr': '27121952.3802199361716584',
#    'priceUsd': '0.4635364264946722',
#    'changePercent24Hr': '9.1200828711856899',
#    'vwap24Hr': '0.4545341212632834',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   {'id': '1inch',
#    'rank': '85',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1143672985.6306298000000000',
#    'maxSupply': None,
#    'marketCapUsd': '631609924.3735281519010212',
#    'volumeUsd24Hr': '26542379.5298885531579818',
#    'priceUsd': '0.5522644429913274',
#    'changePercent24Hr': '8.3017718881166850',
#    'vwap24Hr': '0.5338499240483154',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'celo',
#    'rank': '86',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '530956100.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '625634381.9193801755671000',
#    'volumeUsd24Hr': '43285932.8927360639003175',
#    'priceUsd': '1.1783165913705110',
#    'changePercent24Hr': '11.5011062623995921',
#    'vwap24Hr': '1.1484256895210094',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'ftx-token',
#    'rank': '87',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': '352170015.0000000000000000',
#    'marketCapUsd': '620819156.3769658592921264',
#    'volumeUsd24Hr': '23953841.2003178586810124',
#    'priceUsd': '1.8875901440282750',
#    'changePercent24Hr': '3.8330744900557827',
#    'vwap24Hr': '1.8172782885949056',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'rocket-pool',
#    'rank': '88',
#    'symbol': 'RPL',
#    'name': 'Rocket Pool',
#    'supply': '20141646.6274999400000000',
#    'maxSupply': None,
#    'marketCapUsd': '616794156.3629947080679799',
#    'volumeUsd24Hr': '1430602.0246088118580346',
#    'priceUsd': '30.6228268110348440',
#    'changePercent24Hr': '-1.4703046939208754',
#    'vwap24Hr': '31.4222642682939421',
#    'explorer': 'https://etherscan.io/token/0xb4efd85c19999d84251304bda99e90b92300bd93'},
#   {'id': 'ocean-protocol',
#    'rank': '89',
#    'symbol': 'OCEAN',
#    'name': 'Ocean Protocol',
#    'supply': '568381102.7486407000000000',
#    'maxSupply': '1410000000.0000000000000000',
#    'marketCapUsd': '613376175.0189121341238588',
#    'volumeUsd24Hr': '104736232.4134254920116363',
#    'priceUsd': '1.0791635613018787',
#    'changePercent24Hr': '28.6657749582167754',
#    'vwap24Hr': '0.9876690558628518',
#    'explorer': 'https://etherscan.io/token/0x7AFeBBB46fDb47ed17b22ed075Cde2447694fB9e'},
#   {'id': 'metisdao',
#    'rank': '90',
#    'symbol': 'METIS',
#    'name': 'Metis',
#    'supply': '5250547.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '610090067.4781364674046008',
#    'volumeUsd24Hr': '5304076.2613887734591104',
#    'priceUsd': '116.1955254334713064',
#    'changePercent24Hr': '2.8573990183177314',
#    'vwap24Hr': '114.0835190917500629',
#    'explorer': 'https://etherscan.io/token/0x9e32b13ce7f2e80a01932b42553652e053d6ed8e'},
#   {'id': 'trust-wallet-token',
#    'rank': '91',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '593001113.6404736980637700',
#    'volumeUsd24Hr': '6672456.8392220909916984',
#    'priceUsd': '1.4232599447173123',
#    'changePercent24Hr': '3.4493902714043550',
#    'vwap24Hr': '1.3921446661581924',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'iotex',
#    'rank': '92',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378955.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '581471290.1691469002219435',
#    'volumeUsd24Hr': '12032060.6203000003910347',
#    'priceUsd': '0.0615875385301857',
#    'changePercent24Hr': '3.3160937855242094',
#    'vwap24Hr': '0.0605430381126818',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'skale-network',
#    'rank': '93',
#    'symbol': 'SKL',
#    'name': 'SKALE',
#    'supply': '5179144337.0000000000000000',
#    'maxSupply': '7000000000.0000000000000000',
#    'marketCapUsd': '570593663.5143431246431367',
#    'volumeUsd24Hr': '28500144.1893326290024255',
#    'priceUsd': '0.1101714156599191',
#    'changePercent24Hr': '12.8794585694243067',
#    'vwap24Hr': '0.1046111324721596',
#    'explorer': 'https://etherscan.io/token/0x00c83aecc790e8a4453e5dd3b0b4b3680501a7a7'},
#   {'id': 'siacoin',
#    'rank': '94',
#    'symbol': 'SC',
#    'name': 'Siacoin',
#    'supply': '56517774255.5362200000000000',
#    'maxSupply': None,
#    'marketCapUsd': '563948548.0124698774384055',
#    'volumeUsd24Hr': '23024705.4692801408494401',
#    'priceUsd': '0.0099782511863023',
#    'changePercent24Hr': '5.1676398952779842',
#    'vwap24Hr': '0.0096076439966997',
#    'explorer': 'http://explore.sia.tech/'},
#   {'id': 'holo',
#    'rank': '95',
#    'symbol': 'HOT',
#    'name': 'Holo',
#    'supply': '173026448035.6735200000000000',
#    'maxSupply': None,
#    'marketCapUsd': '549341737.9860136980312548',
#    'volumeUsd24Hr': '13007322.0201518749631914',
#    'priceUsd': '0.0031749003936829',
#    'changePercent24Hr': '14.6478623337614460',
#    'vwap24Hr': '0.0028948846669206',
#    'explorer': 'https://etherscan.io/token/0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#   {'id': 'xinfin-network',
#    'rank': '96',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '512218659.9081012444982989',
#    'volumeUsd24Hr': '13114750.7033438247083186',
#    'priceUsd': '0.0416665118371401',
#    'changePercent24Hr': '1.9295582850085408',
#    'vwap24Hr': '0.0412535719382445',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'zilliqa',
#    'rank': '97',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '17372203179.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '504664281.7406657177080560',
#    'volumeUsd24Hr': '18958268.9755711275504755',
#    'priceUsd': '0.0290501024274640',
#    'changePercent24Hr': '4.6270283932046187',
#    'vwap24Hr': '0.0283337565233492',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'gatetoken',
#    'rank': '98',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '96488036.1205589900000000',
#    'maxSupply': None,
#    'marketCapUsd': '499773208.8766761294369328',
#    'volumeUsd24Hr': '1259687.5541281430369019',
#    'priceUsd': '5.1796391446108828',
#    'changePercent24Hr': '1.3176886992440749',
#    'vwap24Hr': '5.1824211212111655',
#    'explorer': None},
#   {'id': 'origintrail',
#    'rank': '99',
#    'symbol': 'TRAC',
#    'name': 'OriginTrail',
#    'supply': '402324425.4620000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '494852236.4591434609563900',
#    'volumeUsd24Hr': '3964790.4431854838307084',
#    'priceUsd': '1.2299830811686148',
#    'changePercent24Hr': '19.5723450133193765',
#    'vwap24Hr': '1.1262229947127933',
#    'explorer': 'https://etherscan.io/token/0xaa7a9ca87d3694b5755f213b5d04094b8d0f0a6f'},
#   {'id': 'theta-fuel',
#    'rank': '100',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6466192882.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '491892140.7606717517781574',
#    'volumeUsd24Hr': '20101037.5710425228306570',
#    'priceUsd': '0.0760713683827707',
#    'changePercent24Hr': '8.9417084918369754',
#    'vwap24Hr': '0.0757948632623958',
#    'explorer': 'https://explorer.thetatoken.org/'}],
#  'timestamp': 1709336378110}

# %% [markdown]
# Step 2: Transformation (Restructuring and Data Cleaning)

# %%
data = pd.json_normalize(responsedata, "data")
data.head()
# Out:
#              id rank symbol      name                        supply  \
# 0       bitcoin    1    BTC   Bitcoin     19642150.0000000000000000
# 1      ethereum    2    ETH  Ethereum    120142083.8889959300000000
# 2        tether    3   USDT    Tether  98798027729.4258700000000000
# 3  binance-coin    4    BNB       BNB    166801148.0000000000000000
# 4        solana    5    SOL    Solana    442825850.6403168000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1227650565536.9775209764805200
# 1                        None   412941756547.4896949549995262
# 2                        None    98884510857.6484185612044514
# 3  166801148.0000000000000000    68019227592.9661624173445036
# 4                        None    57954352250.4444122682251761
#
#                   volumeUsd24Hr                priceUsd   changePercent24Hr  \
# 0  11986817704.8898693295488357  62500.8242751927625528  1.6200735325408098
# 1   6263091681.9759107837191962   3437.1116529743489174  2.4781714260341641
# 2  25261496631.0563336917951265      1.0008753527799097  0.0155857019675373
# 3    368456630.3002041077465428    407.7863276634412757  1.7736080500951770
# 4   1531722479.3831709204803637    130.8739139023696257  3.8194157105810509
#
#                  vwap24Hr                                           explorer
# 0  61888.9774167814409747                           https://blockchain.info/
# 1   3403.0257068531811405                              https://etherscan.io/
# 2      1.0003141333947072             https://www.omniexplorer.info/asset/31
# 3    405.4560733436612830  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    132.7515549643320709                       https://explorer.solana.com/

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          52 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           99 non-null     object
#  11  explorer           98 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %% [markdown]
# ### Step 3: Converting categorical data into Numerical data

# %%
def convert_columns_to_datatypes(df, column_datatypes):
    for column, datatype in column_datatypes.items():
        if column in df.columns:
            df[column] = df[column].astype(datatype)
    return df

# %%
column_datatypes = {
    'rank': int,
    'supply': float,
    'maxSupply': float,
    'marketCapUsd': float,
    'volumeUsd24Hr': float,
    'priceUsd': float,
    'changePercent24Hr':float,
    'vwap24Hr': float,
}
data = convert_columns_to_datatypes(data, column_datatypes)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int64
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          52 non-null     float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           99 non-null     float64
#  11  explorer           98 non-null     object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# Step 3: Dealing with missing data
# # checking missing data
# # check data type
# # Transform the data

# %%
data["maxSupply"] = data["maxSupply"].fillna(0)
data["vwap24Hr "] = data["vwap24Hr "].fillna(0)
data["explorer"] = data["explorer"].fillna('na')
